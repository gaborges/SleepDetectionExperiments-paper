# %%
import csv
import json
import pandas as pd
from datetime import datetime
import numpy as np
from os.path import exists

from collections import Counter
import warnings
warnings.filterwarnings("ignore")

# %%
outputFolders = "../data_2019_processed/form/"

baseInputFolder = "../../Dataset_ECUADOR_2019/"

# Dataframe of all datasets
# initialize list of lists
datasets = [['0Jf4TH9Zzse0Z1Jjh7SnTOe2MMzeSnFi7feTnkG6vgs'],
            ['0tdmm6rwW3KquQ73ATYYJ5JkpMtvbppJ0VzA2GExdA'], 
            ['2cyV53lVyUtlMj0BRwilEWtYJwUiviYoL48cZBPBq0'], 
            ['2J22RukYnEbKTk7t+iUVDBkorcyL5NKN6TrLe89ys'], 
            #['5FLZBTVAPwdq9QezHE2sVCJIs7p+r6mCemA2gp9jATk'], #does not have the file
            ['7EYF5I04EVqisUJCVNHlqn77UAuOmwL2Dahxd3cA'], 
            ['a9Qgj8ENWrHvl9QqlXcIPKmyGMKgbfHk9Dbqon1HQP4'], 
            ['ae4JJBZDycEcY8McJF+3BxyvZ1619y03BNdCxzpZTc'], 
            ['Ch3u5Oaz96VSrQbf0z31X6jEIbeIekkC0mwPzCdeJ1U'], 
            ['CH8f0yZkZL13zWuE9ks1CkVJRVrr+jsGdUXHrZ6YeA'], 
            ['DHO1K4jgiwZJOfQTrxvKE2vn7hkjamigroGD5IaeRc'], 
            ['DHPqzSqSttiba1L3BD1cptNJPjSxZ8rXxF9mY3za6WA'], 
            ['dQEFscjqnIlug8Tgq97JohhSQPG2DEOWJqS86wCrcY'], 
            ['HFvs2CohmhHte+AaCzFasjzegGzxZKPhkrX23iI6Xo'], 
            ['jgB9E8v3Z6PKdTRTCMAijBllA9YEMtrmHbe4qsbmJWw'], 
            ['JkY++R7E8myldLN3on6iQ78Ee78zCbrLuggfwGju3I'], 
            ['K4SLohf+TN1Ak8Dn8iE3Lme7rEMPISfppB2sXfHX8'], 
            ['oGaWetJJJEWHuvYdWYo826SQxfhCExVVQ2da8LE1Y7Q'], 
            ['pyt24oiDAHsmgWMvkFKz2fn2pwcHiXchd6KchLM'], 
            ['PZCf1nfvhR+6fk+7+sPNMYOgb8BAMmtQtfoRS83Suc'], 
            ['QUNCATForxzK0HHw46LrGOMWh0eVA8Y5XWEiUXX+cQ'], 
            ['rIl2UK9+bQ+tzpFdbJAdbBxEa5GbgrgC030yEaENLw'], 
            ['RoBW3cDOO9wWRMPO2twQff83MPc+OXn6gJ+a1DafreI'], 
            ['SH3kQeyd5volraxw8vOyhlowNqWBPr1IJ9URNXUL4'], 
            ['VVpwFNMrEglveh6MDN8lrRzTy5OwzglD4FURfM4A2is'], 
            ['Wa1mcNmbh66S7VS6GIzyfCFMD3SGhbtDQyFP1ywJEsw'], 
            ['XCKRE0BWRHxfP1kZIihgtT+jUjSp2GE8v5ZlhcIhVmA'], 
            ['YI5Y79K6GXqAUoGP6PNyII8WKlAoel4urDxWSVVOvBw'], 
            ['ypklj+8GJ15rOIH1lpKQtFJOuK+VdvyCuBPqhY3aoM'], 
            ['ZSsAZ0Pq+MCqFrnjsRFn5Ua09pMCVaOV9c8ZuYb7XQY']]
  
# Create the pandas DataFrame
folders = pd.DataFrame(datasets, columns=['folder'])

# %%
#pd.read_csv("../Dataset_ECUADOR_2019/oGaWetJJJEWHuvYdWYo826SQxfhCExVVQ2da8LE1Y7Q/sleep_form_oGaWetJJJEWHuvYdWYo826SQxfhCExVVQ2da8LE1Y7Q.csv") # testFile = "../Dataset_ECUADOR_2019/oGaWetJJJEWHuvYdWYo826SQxfhCExVVQ2da8LE1Y7Q/sleep_form_oGaWetJJJEWHuvYdWYo826SQxfhCExVVQ2da8LE1Y7Q.csv"

# %%
def isSameDayConflict(timestampA,timestampB): # limit 
    #2018-06-02T15:21:58Z
    onlyDateA =  timestampA.split("T")
    onlyDateB =  timestampB.split("T")
    tempA = datetime.strptime(onlyDateA[0],'%Y-%m-%d').timestamp()
    tempB = datetime.strptime(onlyDateB[0],'%Y-%m-%d').timestamp()
    if(tempA==tempB):
        return True
    else:
        return False

def mapDuplicatedReports(dataframe):
    # create duplicated column flag, if it not exists
    #if not ('duplicated' in dataframe.columns):
    dataframe['duplicated'] = 0
    # limit must be -1 because we compare with the next value
    limit = dataframe.shape[0] - 1
    # reset index
    dataframe = dataframe.reset_index()
    # do the analysis
    for index in range(0,limit):
        current = dataframe['wakeup_time'][index]
        #print(current)
        if current >= dataframe['sleep_time'][index+1]:
            #print(index,dataframe['sleep_time'][index],dataframe['time_sleeping_s'][index],dataframe['wakeup_time'][index],dataframe['timestamp'][index])
            #print(dataframe['timestamp'][index],dataframe['timestamp'][index+1])
            if isSameDayConflict(dataframe['timestamp'][index],dataframe['timestamp'][index+1]):
                dataframe['duplicated'][index] = 1
                dataframe['duplicated'][index+1] = 0
    return dataframe
                
print("Conflict",isSameDayConflict('2018-06-02T15:21:58Z','2018-06-02T15:21:58Z'))
print("Not conflict",isSameDayConflict('2018-06-02T15:21:58Z','2018-06-03T15:21:58Z'))
# Out:
# Conflict True
# Not conflict False

# %%
print("Generation: script to deal with negative sleep times and other issues")
test = []
temposDuplicadas = 0
temposMaioresDe12 = 0
temposNegativos = 0
temposTotal = 0
temposUseful = 0

for indexFolder, folder in folders.iterrows():
    #testFile = "2J22RukYnEbKTk7t+iUVDBkorcyL5NKN6TrLe89ys2J22RukYnEbKTk7t+iUVDBkorcyL5NKN6TrLe89ys.csv"
    
    # check f the path exists (becouse kaggle removed the + character from file names)
    formFileName = "sleep_form_"+folder['folder']+".csv"
    if(not(exists(baseInputFolder+folder['folder']+"/"+formFileName))):
        formFileName = "sleep_form_"+folder['folder'].replace("+","")+".csv"
        
    print(formFileName)
    file = baseInputFolder+folder['folder']+"/"+formFileName
    dataset = pd.read_csv(file)
    data = dict()
    
    # test transformation
    dataframe = dataset
    # sleep_time to timestamp
    for indexFolder, content in dataframe['sleep_time'].items():
        temp = datetime.strptime(content,'%Y-%m-%dT%H:%M:%SZ')
        dataframe['sleep_time'][indexFolder] = temp.timestamp()

    # wakeup_time to timestamp
    for indexFolder, content in dataframe['wakeup_time'].items():
        temp = datetime.strptime(content,'%Y-%m-%dT%H:%M:%SZ')
        dataframe['wakeup_time'][indexFolder] = temp.timestamp() 
        
        # verify if the wakeup_time and sleep_time are inverted
        temp_time = dataframe['sleep_time'][indexFolder]
        if(temp_time > dataframe['wakeup_time'][indexFolder]):
            dataframe['sleep_time'][indexFolder]  = dataframe['wakeup_time'][indexFolder]
            dataframe['wakeup_time'][indexFolder] = temp_time

    # time sleeling in seconds
    dataframe['time_sleeping'] = dataframe['wakeup_time'] - dataframe['sleep_time']
    # convert time sleeping to hours
    dataframe['time_sleeping_hs'] = dataframe['time_sleeping'] /60/60
    
    # replace in 12hs of max sleeping
    #for indexFolder, content in dataframe['time_sleeping_hs'].items():
    #    if(content > 12.0):
    #       dataframe['time_sleeping'][indexFolder] = 24.0 *60 *60
    #       dataframe['time_sleeping_hs'][indexFolder] = 24.0
    #       dataframe['wakeup_time'][indexFolder] = dataframe['sleep_time'][indexFolder] + dataframe['time_sleeping'][indexFolder]
    
    # remove forms with more than then 25hs
    #dfOnlyWithLess12hs = dataframe.loc[dataframe['time_sleeping_hs'] <= 24.0]
    # map forms with same day of report
    dfOnlyUnique = mapDuplicatedReports(dataframe)
    # remove duplicates
    dfOnlyUnique = dfOnlyUnique.loc[dfOnlyUnique['duplicated'] == 0]
    # remove forms with zero hours of sleep
    dfOnlyUseful = dfOnlyUnique.loc[dfOnlyUnique['time_sleeping_hs'] > 0.0]
   
    temposTotal = temposTotal + dataframe.shape[0]
    #temposMaioresDe12 = temposMaioresDe12 + dataframe.shape[0]-dfOnlyWithLess12hs.shape[0]
    temposDuplicadas = temposDuplicadas + (dataframe.shape[0]-dfOnlyUnique.shape[0])
    temposNegativos = temposNegativos + dfOnlyUnique.loc[dfOnlyUnique['time_sleeping_hs'] <= 0.0].shape[0] 
    temposUseful = temposUseful + dfOnlyUseful.shape[0]
    
    # write in file
    #fileOutput = outputFolders+"sleep_form_"+folder['folder']+"_treated.csv"
    #dfOnlyUseful.to_csv(fileOutput)
        
    print("")
    print("")
    print("")
    print("Client: ",folder['folder'])
    print("Total count: ",dataframe.shape[0])
    #print("Count with less 24hs: ",dfOnlyWithLess12hs.shape[0], " - removed: ",dataframe.shape[0]-dfOnlyWithLess12hs.shape[0])
    print("Count without duplicates: ",dfOnlyUnique.shape[0]," - removed: ",dataframe.shape[0]-dfOnlyUnique.shape[0])
    print("Count negatives: ",dfOnlyUnique.loc[dfOnlyUnique['time_sleeping_hs'] <= 0.0].shape[0])
    print("Count useful: ",dfOnlyUseful.shape[0])
    #print([dataframe['time_sleeping'],dataframe['time_sleeping']])
    #test.append(data)
    
temposNormais = temposTotal - temposDuplicadas - temposMaioresDe12 - temposNegativos
print("")
print("")
print("")
print("Total:",temposTotal)    
print("duplicated:",temposDuplicadas)
#print(">24:",temposMaioresDe12)
#print("0-24:",temposNormais, "useful")
print("<=0:",temposNegativos)
print("Useful:",temposUseful, "useful")
# Out:
# Generation: script to deal with negative sleep times and other issues
# sleep_form_0Jf4TH9Zzse0Z1Jjh7SnTOe2MMzeSnFi7feTnkG6vgs.csv
#
#
#
# Client:  0Jf4TH9Zzse0Z1Jjh7SnTOe2MMzeSnFi7feTnkG6vgs
# Total count:  33
# Count without duplicates:  26  - removed:  7
# Count negatives:  0
# Count useful:  26
# sleep_form_0tdmm6rwW3KquQ73ATYYJ5JkpMtvbppJ0VzA2GExdA.csv
#
#
#
# Client:  0tdmm6rwW3KquQ73ATYYJ5JkpMtvbppJ0VzA2GExdA
# Total count:  31
# Count without duplicates:  22  - removed:  9
# Count negatives:  0
# Count useful:  22
# sleep_form_2cyV53lVyUtlMj0BRwilEWtYJwUiviYoL48cZBPBq0.csv
#
#
#
# Client:  2cyV53lVyUtlMj0BRwilEWtYJwUiviYoL48cZBPBq0
# Total count:  48
# Count without duplicates:  30  - removed:  18
# Count negatives:  0
# Count useful:  30
# sleep_form_2J22RukYnEbKTk7t+iUVDBkorcyL5NKN6TrLe89ys.csv
#
#
#
# Client:  2J22RukYnEbKTk7t+iUVDBkorcyL5NKN6TrLe89ys
# Total count:  50
# Count without duplicates:  21  - removed:  29
# Count negatives:  0
# Count useful:  21
# sleep_form_7EYF5I04EVqisUJCVNHlqn77UAuOmwL2Dahxd3cA.csv
#
#
#
# Client:  7EYF5I04EVqisUJCVNHlqn77UAuOmwL2Dahxd3cA
# Total count:  15
# Count without duplicates:  14  - removed:  1
# Count negatives:  0
# Count useful:  14
# sleep_form_a9Qgj8ENWrHvl9QqlXcIPKmyGMKgbfHk9Dbqon1HQP4.csv
#
#
#
# Client:  a9Qgj8ENWrHvl9QqlXcIPKmyGMKgbfHk9Dbqon1HQP4
# Total count:  50
# Count without duplicates:  25  - removed:  25
# Count negatives:  0
# Count useful:  25
# sleep_form_ae4JJBZDycEcY8McJF+3BxyvZ1619y03BNdCxzpZTc.csv
#
#
#
# Client:  ae4JJBZDycEcY8McJF+3BxyvZ1619y03BNdCxzpZTc
# Total count:  22
# Count without duplicates:  18  - removed:  4
# Count negatives:  0
# Count useful:  18
# sleep_form_Ch3u5Oaz96VSrQbf0z31X6jEIbeIekkC0mwPzCdeJ1U.csv
#
#
#
# Client:  Ch3u5Oaz96VSrQbf0z31X6jEIbeIekkC0mwPzCdeJ1U
# Total count:  53
# Count without duplicates:  29  - removed:  24
# Count negatives:  0
# Count useful:  29
# sleep_form_CH8f0yZkZL13zWuE9ks1CkVJRVrr+jsGdUXHrZ6YeA.csv
#
#
#
# Client:  CH8f0yZkZL13zWuE9ks1CkVJRVrr+jsGdUXHrZ6YeA
# Total count:  66
# Count without duplicates:  29  - removed:  37
# Count negatives:  2
# Count useful:  27
# sleep_form_DHO1K4jgiwZJOfQTrxvKE2vn7hkjamigroGD5IaeRc.csv
#
#
#
# Client:  DHO1K4jgiwZJOfQTrxvKE2vn7hkjamigroGD5IaeRc
# Total count:  22
# Count without duplicates:  21  - removed:  1
# Count negatives:  0
# Count useful:  21
# sleep_form_DHPqzSqSttiba1L3BD1cptNJPjSxZ8rXxF9mY3za6WA.csv
#
#
#
# Client:  DHPqzSqSttiba1L3BD1cptNJPjSxZ8rXxF9mY3za6WA
# Total count:  6
# Count without duplicates:  3  - removed:  3
# Count negatives:  0
# Count useful:  3
# sleep_form_dQEFscjqnIlug8Tgq97JohhSQPG2DEOWJqS86wCrcY.csv
#
#
#
# Client:  dQEFscjqnIlug8Tgq97JohhSQPG2DEOWJqS86wCrcY
# Total count:  66
# Count without duplicates:  32  - removed:  34
# Count negatives:  0
# Count useful:  32
# sleep_form_HFvs2CohmhHte+AaCzFasjzegGzxZKPhkrX23iI6Xo.csv
#
#
#
# Client:  HFvs2CohmhHte+AaCzFasjzegGzxZKPhkrX23iI6Xo
# Total count:  49
# Count without duplicates:  27  - removed:  22
# Count negatives:  0
# Count useful:  27
# sleep_form_jgB9E8v3Z6PKdTRTCMAijBllA9YEMtrmHbe4qsbmJWw.csv
#
#
#
# Client:  jgB9E8v3Z6PKdTRTCMAijBllA9YEMtrmHbe4qsbmJWw
# Total count:  28
# Count without duplicates:  25  - removed:  3
# Count negatives:  0
# Count useful:  25
# sleep_form_JkY++R7E8myldLN3on6iQ78Ee78zCbrLuggfwGju3I.csv
#
#
#
# Client:  JkY++R7E8myldLN3on6iQ78Ee78zCbrLuggfwGju3I
# Total count:  52
# Count without duplicates:  30  - removed:  22
# Count negatives:  0
# Count useful:  30
# sleep_form_K4SLohf+TN1Ak8Dn8iE3Lme7rEMPISfppB2sXfHX8.csv
#
#
#
# Client:  K4SLohf+TN1Ak8Dn8iE3Lme7rEMPISfppB2sXfHX8
# Total count:  42
# Count without duplicates:  23  - removed:  19
# Count negatives:  0
# Count useful:  23
# sleep_form_oGaWetJJJEWHuvYdWYo826SQxfhCExVVQ2da8LE1Y7Q.csv
#
#
#
# Client:  oGaWetJJJEWHuvYdWYo826SQxfhCExVVQ2da8LE1Y7Q
# Total count:  50
# Count without duplicates:  39  - removed:  11
# Count negatives:  2
# Count useful:  37
# sleep_form_pyt24oiDAHsmgWMvkFKz2fn2pwcHiXchd6KchLM.csv
#
#
#
# Client:  pyt24oiDAHsmgWMvkFKz2fn2pwcHiXchd6KchLM
# Total count:  22
# Count without duplicates:  20  - removed:  2
# Count negatives:  0
# Count useful:  20
# sleep_form_PZCf1nfvhR+6fk+7+sPNMYOgb8BAMmtQtfoRS83Suc.csv
#
#
#
# Client:  PZCf1nfvhR+6fk+7+sPNMYOgb8BAMmtQtfoRS83Suc
# Total count:  9
# Count without duplicates:  7  - removed:  2
# Count negatives:  0
# Count useful:  7
# sleep_form_QUNCATForxzK0HHw46LrGOMWh0eVA8Y5XWEiUXX+cQ.csv
#
#
#
# Client:  QUNCATForxzK0HHw46LrGOMWh0eVA8Y5XWEiUXX+cQ
# Total count:  28
# Count without duplicates:  23  - removed:  5
# Count negatives:  0
# Count useful:  23
# sleep_form_rIl2UK9+bQ+tzpFdbJAdbBxEa5GbgrgC030yEaENLw.csv
#
#
#
# Client:  rIl2UK9+bQ+tzpFdbJAdbBxEa5GbgrgC030yEaENLw
# Total count:  19
# Count without duplicates:  19  - removed:  0
# Count negatives:  0
# Count useful:  19
# sleep_form_RoBW3cDOO9wWRMPO2twQff83MPc+OXn6gJ+a1DafreI.csv
#
#
#
# Client:  RoBW3cDOO9wWRMPO2twQff83MPc+OXn6gJ+a1DafreI
# Total count:  40
# Count without duplicates:  29  - removed:  11
# Count negatives:  0
# Count useful:  29
# sleep_form_SH3kQeyd5volraxw8vOyhlowNqWBPr1IJ9URNXUL4.csv
#
#
#
# Client:  SH3kQeyd5volraxw8vOyhlowNqWBPr1IJ9URNXUL4
# Total count:  20
# Count without duplicates:  19  - removed:  1
# Count negatives:  0
# Count useful:  19
# sleep_form_VVpwFNMrEglveh6MDN8lrRzTy5OwzglD4FURfM4A2is.csv
#
#
#
# Client:  VVpwFNMrEglveh6MDN8lrRzTy5OwzglD4FURfM4A2is
# Total count:  38
# Count without duplicates:  26  - removed:  12
# Count negatives:  0
# Count useful:  26
# sleep_form_Wa1mcNmbh66S7VS6GIzyfCFMD3SGhbtDQyFP1ywJEsw.csv
#
#
#
# Client:  Wa1mcNmbh66S7VS6GIzyfCFMD3SGhbtDQyFP1ywJEsw
# Total count:  24
# Count without duplicates:  16  - removed:  8
# Count negatives:  0
# Count useful:  16
# sleep_form_XCKRE0BWRHxfP1kZIihgtT+jUjSp2GE8v5ZlhcIhVmA.csv
#
#
#
# Client:  XCKRE0BWRHxfP1kZIihgtT+jUjSp2GE8v5ZlhcIhVmA
# Total count:  35
# Count without duplicates:  27  - removed:  8
# Count negatives:  0
# Count useful:  27
# sleep_form_YI5Y79K6GXqAUoGP6PNyII8WKlAoel4urDxWSVVOvBw.csv
#
#
#
# Client:  YI5Y79K6GXqAUoGP6PNyII8WKlAoel4urDxWSVVOvBw
# Total count:  25
# Count without duplicates:  25  - removed:  0
# Count negatives:  0
# Count useful:  25
# sleep_form_ypklj+8GJ15rOIH1lpKQtFJOuK+VdvyCuBPqhY3aoM.csv
#
#
#
# Client:  ypklj+8GJ15rOIH1lpKQtFJOuK+VdvyCuBPqhY3aoM
# Total count:  1
# Count without duplicates:  1  - removed:  0
# Count negatives:  0
# Count useful:  1
# sleep_form_ZSsAZ0Pq+MCqFrnjsRFn5Ua09pMCVaOV9c8ZuYb7XQY.csv
#
#
#
# Client:  ZSsAZ0Pq+MCqFrnjsRFn5Ua09pMCVaOV9c8ZuYb7XQY
# Total count:  21
# Count without duplicates:  21  - removed:  0
# Count negatives:  1
# Count useful:  20
#
#
#
# Total: 965
# duplicated: 318
# <=0: 5
# Useful: 642 useful

# %%
print("Generation: script to deal with negative sleep times and other issues")
test = []
temposDuplicadas = 0
temposMaioresDe12 = 0
temposNegativos = 0
temposTotal = 0
temposUseful = 0

for indexFolder, folder in folders.iterrows():
    #testFile = "2J22RukYnEbKTk7t+iUVDBkorcyL5NKN6TrLe89ys2J22RukYnEbKTk7t+iUVDBkorcyL5NKN6TrLe89ys.csv"
    
    # check f the path exists (becouse kaggle removed the + character from file names)
    formFileName = "sleep_form_"+folder['folder']+".csv"
    if(not(exists(baseInputFolder+folder['folder']+"/"+formFileName))):
        formFileName = "sleep_form_"+folder['folder'].replace("+","")+".csv"
        
    print(formFileName)
    file = baseInputFolder+folder['folder']+"/"+formFileName
    dataset = pd.read_csv(file)
    data = dict()
    
    # test transformation
    dataframe = dataset
    # sleep_time to timestamp
    for indexFolder, content in dataframe['sleep_time'].items():
        temp = datetime.strptime(content,'%Y-%m-%dT%H:%M:%SZ')
        dataframe['sleep_time'][indexFolder] = temp.timestamp()

    # wakeup_time to timestamp
    for indexFolder, content in dataframe['wakeup_time'].items():
        temp = datetime.strptime(content,'%Y-%m-%dT%H:%M:%SZ')
        dataframe['wakeup_time'][indexFolder] = temp.timestamp() 
        
        # verify if the wakeup_time and sleep_time are inverted
        temp_time = dataframe['sleep_time'][indexFolder]
        if(temp_time > dataframe['wakeup_time'][indexFolder]):
            dataframe['sleep_time'][indexFolder]  = dataframe['wakeup_time'][indexFolder]
            dataframe['wakeup_time'][indexFolder] = temp_time

    # time sleeling in seconds
    dataframe['time_sleeping'] = dataframe['wakeup_time'] - dataframe['sleep_time']
    # convert time sleeping to hours
    dataframe['time_sleeping_hs'] = dataframe['time_sleeping'] /60/60
    
    # replace in 12hs of max sleeping
    #for indexFolder, content in dataframe['time_sleeping_hs'].items():
    #    if(content > 12.0):
    #       dataframe['time_sleeping'][indexFolder] = 24.0 *60 *60
    #       dataframe['time_sleeping_hs'][indexFolder] = 24.0
    #       dataframe['wakeup_time'][indexFolder] = dataframe['sleep_time'][indexFolder] + dataframe['time_sleeping'][indexFolder]
    
    # remove forms with more than then 25hs
    #dfOnlyWithLess12hs = dataframe.loc[dataframe['time_sleeping_hs'] <= 24.0]
    # map forms with same day of report
    dfOnlyUnique = mapDuplicatedReports(dataframe)
    # remove duplicates
    dfOnlyUnique = dfOnlyUnique.loc[dfOnlyUnique['duplicated'] == 0]
    # remove forms with zero hours of sleep
    dfOnlyUseful = dfOnlyUnique.loc[dfOnlyUnique['time_sleeping_hs'] > 0.0]
   
    temposTotal = temposTotal + dataframe.shape[0]
    #temposMaioresDe12 = temposMaioresDe12 + dataframe.shape[0]-dfOnlyWithLess12hs.shape[0]
    temposDuplicadas = temposDuplicadas + (dataframe.shape[0]-dfOnlyUnique.shape[0])
    temposNegativos = temposNegativos + dfOnlyUnique.loc[dfOnlyUnique['time_sleeping_hs'] <= 0.0].shape[0] 
    temposUseful = temposUseful + dfOnlyUseful.shape[0]
    
    # write in file
    fileOutput = outputFolders+"sleep_form_"+folder['folder']+"_treated.csv"
    dfOnlyUseful.to_csv(fileOutput)
        
    print("")
    print("")
    print("")
    print("Client: ",folder['folder'])
    print("Total count: ",dataframe.shape[0])
    #print("Count with less 24hs: ",dfOnlyWithLess12hs.shape[0], " - removed: ",dataframe.shape[0]-dfOnlyWithLess12hs.shape[0])
    print("Count without duplicates: ",dfOnlyUnique.shape[0]," - removed: ",dataframe.shape[0]-dfOnlyUnique.shape[0])
    print("Count negatives: ",dfOnlyUnique.loc[dfOnlyUnique['time_sleeping_hs'] <= 0.0].shape[0])
    print("Count useful: ",dfOnlyUseful.shape[0])
    #print([dataframe['time_sleeping'],dataframe['time_sleeping']])
    #test.append(data)
    
temposNormais = temposTotal - temposDuplicadas - temposMaioresDe12 - temposNegativos
print("")
print("")
print("")
print("Total:",temposTotal)    
print("duplicated:",temposDuplicadas)
#print(">24:",temposMaioresDe12)
#print("0-24:",temposNormais, "useful")
print("<=0:",temposNegativos)
print("Useful:",temposUseful, "useful")
# Out:
# Generation: script to deal with negative sleep times and other issues
# sleep_form_0Jf4TH9Zzse0Z1Jjh7SnTOe2MMzeSnFi7feTnkG6vgs.csv
#
#
#
# Client:  0Jf4TH9Zzse0Z1Jjh7SnTOe2MMzeSnFi7feTnkG6vgs
# Total count:  33
# Count without duplicates:  26  - removed:  7
# Count negatives:  0
# Count useful:  26
# sleep_form_0tdmm6rwW3KquQ73ATYYJ5JkpMtvbppJ0VzA2GExdA.csv
#
#
#
# Client:  0tdmm6rwW3KquQ73ATYYJ5JkpMtvbppJ0VzA2GExdA
# Total count:  31
# Count without duplicates:  22  - removed:  9
# Count negatives:  0
# Count useful:  22
# sleep_form_2cyV53lVyUtlMj0BRwilEWtYJwUiviYoL48cZBPBq0.csv
#
#
#
# Client:  2cyV53lVyUtlMj0BRwilEWtYJwUiviYoL48cZBPBq0
# Total count:  48
# Count without duplicates:  30  - removed:  18
# Count negatives:  0
# Count useful:  30
# sleep_form_2J22RukYnEbKTk7t+iUVDBkorcyL5NKN6TrLe89ys.csv
#
#
#
# Client:  2J22RukYnEbKTk7t+iUVDBkorcyL5NKN6TrLe89ys
# Total count:  50
# Count without duplicates:  21  - removed:  29
# Count negatives:  0
# Count useful:  21
# sleep_form_7EYF5I04EVqisUJCVNHlqn77UAuOmwL2Dahxd3cA.csv
#
#
#
# Client:  7EYF5I04EVqisUJCVNHlqn77UAuOmwL2Dahxd3cA
# Total count:  15
# Count without duplicates:  14  - removed:  1
# Count negatives:  0
# Count useful:  14
# sleep_form_a9Qgj8ENWrHvl9QqlXcIPKmyGMKgbfHk9Dbqon1HQP4.csv
#
#
#
# Client:  a9Qgj8ENWrHvl9QqlXcIPKmyGMKgbfHk9Dbqon1HQP4
# Total count:  50
# Count without duplicates:  25  - removed:  25
# Count negatives:  0
# Count useful:  25
# sleep_form_ae4JJBZDycEcY8McJF+3BxyvZ1619y03BNdCxzpZTc.csv
#
#
#
# Client:  ae4JJBZDycEcY8McJF+3BxyvZ1619y03BNdCxzpZTc
# Total count:  22
# Count without duplicates:  18  - removed:  4
# Count negatives:  0
# Count useful:  18
# sleep_form_Ch3u5Oaz96VSrQbf0z31X6jEIbeIekkC0mwPzCdeJ1U.csv
#
#
#
# Client:  Ch3u5Oaz96VSrQbf0z31X6jEIbeIekkC0mwPzCdeJ1U
# Total count:  53
# Count without duplicates:  29  - removed:  24
# Count negatives:  0
# Count useful:  29
# sleep_form_CH8f0yZkZL13zWuE9ks1CkVJRVrr+jsGdUXHrZ6YeA.csv
#
#
#
# Client:  CH8f0yZkZL13zWuE9ks1CkVJRVrr+jsGdUXHrZ6YeA
# Total count:  66
# Count without duplicates:  29  - removed:  37
# Count negatives:  2
# Count useful:  27
# sleep_form_DHO1K4jgiwZJOfQTrxvKE2vn7hkjamigroGD5IaeRc.csv
#
#
#
# Client:  DHO1K4jgiwZJOfQTrxvKE2vn7hkjamigroGD5IaeRc
# Total count:  22
# Count without duplicates:  21  - removed:  1
# Count negatives:  0
# Count useful:  21
# sleep_form_DHPqzSqSttiba1L3BD1cptNJPjSxZ8rXxF9mY3za6WA.csv
#
#
#
# Client:  DHPqzSqSttiba1L3BD1cptNJPjSxZ8rXxF9mY3za6WA
# Total count:  6
# Count without duplicates:  3  - removed:  3
# Count negatives:  0
# Count useful:  3
# sleep_form_dQEFscjqnIlug8Tgq97JohhSQPG2DEOWJqS86wCrcY.csv
#
#
#
# Client:  dQEFscjqnIlug8Tgq97JohhSQPG2DEOWJqS86wCrcY
# Total count:  66
# Count without duplicates:  32  - removed:  34
# Count negatives:  0
# Count useful:  32
# sleep_form_HFvs2CohmhHte+AaCzFasjzegGzxZKPhkrX23iI6Xo.csv
#
#
#
# Client:  HFvs2CohmhHte+AaCzFasjzegGzxZKPhkrX23iI6Xo
# Total count:  49
# Count without duplicates:  27  - removed:  22
# Count negatives:  0
# Count useful:  27
# sleep_form_jgB9E8v3Z6PKdTRTCMAijBllA9YEMtrmHbe4qsbmJWw.csv
#
#
#
# Client:  jgB9E8v3Z6PKdTRTCMAijBllA9YEMtrmHbe4qsbmJWw
# Total count:  28
# Count without duplicates:  25  - removed:  3
# Count negatives:  0
# Count useful:  25
# sleep_form_JkY++R7E8myldLN3on6iQ78Ee78zCbrLuggfwGju3I.csv
#
#
#
# Client:  JkY++R7E8myldLN3on6iQ78Ee78zCbrLuggfwGju3I
# Total count:  52
# Count without duplicates:  30  - removed:  22
# Count negatives:  0
# Count useful:  30
# sleep_form_K4SLohf+TN1Ak8Dn8iE3Lme7rEMPISfppB2sXfHX8.csv
#
#
#
# Client:  K4SLohf+TN1Ak8Dn8iE3Lme7rEMPISfppB2sXfHX8
# Total count:  42
# Count without duplicates:  23  - removed:  19
# Count negatives:  0
# Count useful:  23
# sleep_form_oGaWetJJJEWHuvYdWYo826SQxfhCExVVQ2da8LE1Y7Q.csv
#
#
#
# Client:  oGaWetJJJEWHuvYdWYo826SQxfhCExVVQ2da8LE1Y7Q
# Total count:  50
# Count without duplicates:  39  - removed:  11
# Count negatives:  2
# Count useful:  37
# sleep_form_pyt24oiDAHsmgWMvkFKz2fn2pwcHiXchd6KchLM.csv
#
#
#
# Client:  pyt24oiDAHsmgWMvkFKz2fn2pwcHiXchd6KchLM
# Total count:  22
# Count without duplicates:  20  - removed:  2
# Count negatives:  0
# Count useful:  20
# sleep_form_PZCf1nfvhR+6fk+7+sPNMYOgb8BAMmtQtfoRS83Suc.csv
#
#
#
# Client:  PZCf1nfvhR+6fk+7+sPNMYOgb8BAMmtQtfoRS83Suc
# Total count:  9
# Count without duplicates:  7  - removed:  2
# Count negatives:  0
# Count useful:  7
# sleep_form_QUNCATForxzK0HHw46LrGOMWh0eVA8Y5XWEiUXX+cQ.csv
#
#
#
# Client:  QUNCATForxzK0HHw46LrGOMWh0eVA8Y5XWEiUXX+cQ
# Total count:  28
# Count without duplicates:  23  - removed:  5
# Count negatives:  0
# Count useful:  23
# sleep_form_rIl2UK9+bQ+tzpFdbJAdbBxEa5GbgrgC030yEaENLw.csv
#
#
#
# Client:  rIl2UK9+bQ+tzpFdbJAdbBxEa5GbgrgC030yEaENLw
# Total count:  19
# Count without duplicates:  19  - removed:  0
# Count negatives:  0
# Count useful:  19
# sleep_form_RoBW3cDOO9wWRMPO2twQff83MPc+OXn6gJ+a1DafreI.csv
#
#
#
# Client:  RoBW3cDOO9wWRMPO2twQff83MPc+OXn6gJ+a1DafreI
# Total count:  40
# Count without duplicates:  29  - removed:  11
# Count negatives:  0
# Count useful:  29
# sleep_form_SH3kQeyd5volraxw8vOyhlowNqWBPr1IJ9URNXUL4.csv
#
#
#
# Client:  SH3kQeyd5volraxw8vOyhlowNqWBPr1IJ9URNXUL4
# Total count:  20
# Count without duplicates:  19  - removed:  1
# Count negatives:  0
# Count useful:  19
# sleep_form_VVpwFNMrEglveh6MDN8lrRzTy5OwzglD4FURfM4A2is.csv
#
#
#
# Client:  VVpwFNMrEglveh6MDN8lrRzTy5OwzglD4FURfM4A2is
# Total count:  38
# Count without duplicates:  26  - removed:  12
# Count negatives:  0
# Count useful:  26
# sleep_form_Wa1mcNmbh66S7VS6GIzyfCFMD3SGhbtDQyFP1ywJEsw.csv
#
#
#
# Client:  Wa1mcNmbh66S7VS6GIzyfCFMD3SGhbtDQyFP1ywJEsw
# Total count:  24
# Count without duplicates:  16  - removed:  8
# Count negatives:  0
# Count useful:  16
# sleep_form_XCKRE0BWRHxfP1kZIihgtT+jUjSp2GE8v5ZlhcIhVmA.csv
#
#
#
# Client:  XCKRE0BWRHxfP1kZIihgtT+jUjSp2GE8v5ZlhcIhVmA
# Total count:  35
# Count without duplicates:  27  - removed:  8
# Count negatives:  0
# Count useful:  27
# sleep_form_YI5Y79K6GXqAUoGP6PNyII8WKlAoel4urDxWSVVOvBw.csv
#
#
#
# Client:  YI5Y79K6GXqAUoGP6PNyII8WKlAoel4urDxWSVVOvBw
# Total count:  25
# Count without duplicates:  25  - removed:  0
# Count negatives:  0
# Count useful:  25
# sleep_form_ypklj+8GJ15rOIH1lpKQtFJOuK+VdvyCuBPqhY3aoM.csv
#
#
#
# Client:  ypklj+8GJ15rOIH1lpKQtFJOuK+VdvyCuBPqhY3aoM
# Total count:  1
# Count without duplicates:  1  - removed:  0
# Count negatives:  0
# Count useful:  1
# sleep_form_ZSsAZ0Pq+MCqFrnjsRFn5Ua09pMCVaOV9c8ZuYb7XQY.csv
#
#
#
# Client:  ZSsAZ0Pq+MCqFrnjsRFn5Ua09pMCVaOV9c8ZuYb7XQY
# Total count:  21
# Count without duplicates:  21  - removed:  0
# Count negatives:  1
# Count useful:  20
#
#
#
# Total: 965
# duplicated: 318
# <=0: 5
# Useful: 642 useful
