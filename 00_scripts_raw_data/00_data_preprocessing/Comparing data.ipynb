# %%
import csv
import json
import pandas as pd
from datetime import datetime
import numpy as np
from collections import Counter


import warnings
warnings.filterwarnings("ignore")


localFolder = "../data_2019_processed/"
baseFolder = "../../Dataset_ECUADOR_2019/"

# %%
# Dataframe of all datasets
# initialize list of lists
datasets = [['0Jf4TH9Zzse0Z1Jjh7SnTOe2MMzeSnFi7feTnkG6vgs'],
            ['0tdmm6rwW3KquQ73ATYYJ5JkpMtvbppJ0VzA2GExdA'], 
            ['2cyV53lVyUtlMj0BRwilEWtYJwUiviYoL48cZBPBq0'], 
            ['2J22RukYnEbKTk7t+iUVDBkorcyL5NKN6TrLe89ys'], 
            #['5FLZBTVAPwdq9QezHE2sVCJIs7p+r6mCemA2gp9jATk'], #does not have the file
            ['7EYF5I04EVqisUJCVNHlqn77UAuOmwL2Dahxd3cA'], 
            ['a9Qgj8ENWrHvl9QqlXcIPKmyGMKgbfHk9Dbqon1HQP4'], 
            ['ae4JJBZDycEcY8McJF+3BxyvZ1619y03BNdCxzpZTc'], 
            ['Ch3u5Oaz96VSrQbf0z31X6jEIbeIekkC0mwPzCdeJ1U'], 
            ['CH8f0yZkZL13zWuE9ks1CkVJRVrr+jsGdUXHrZ6YeA'], 
            ['DHO1K4jgiwZJOfQTrxvKE2vn7hkjamigroGD5IaeRc'], 
            ['DHPqzSqSttiba1L3BD1cptNJPjSxZ8rXxF9mY3za6WA'], 
            ['dQEFscjqnIlug8Tgq97JohhSQPG2DEOWJqS86wCrcY'], 
            ['HFvs2CohmhHte+AaCzFasjzegGzxZKPhkrX23iI6Xo'], 
            ['jgB9E8v3Z6PKdTRTCMAijBllA9YEMtrmHbe4qsbmJWw'], 
            ['JkY++R7E8myldLN3on6iQ78Ee78zCbrLuggfwGju3I'], 
            ['K4SLohf+TN1Ak8Dn8iE3Lme7rEMPISfppB2sXfHX8'], 
            ['oGaWetJJJEWHuvYdWYo826SQxfhCExVVQ2da8LE1Y7Q'], 
            ['pyt24oiDAHsmgWMvkFKz2fn2pwcHiXchd6KchLM'], 
            ['PZCf1nfvhR+6fk+7+sPNMYOgb8BAMmtQtfoRS83Suc'], 
            ['QUNCATForxzK0HHw46LrGOMWh0eVA8Y5XWEiUXX+cQ'], 
            ['rIl2UK9+bQ+tzpFdbJAdbBxEa5GbgrgC030yEaENLw'], 
            ['RoBW3cDOO9wWRMPO2twQff83MPc+OXn6gJ+a1DafreI'], 
            ['SH3kQeyd5volraxw8vOyhlowNqWBPr1IJ9URNXUL4'], 
            ['VVpwFNMrEglveh6MDN8lrRzTy5OwzglD4FURfM4A2is'], 
            ['Wa1mcNmbh66S7VS6GIzyfCFMD3SGhbtDQyFP1ywJEsw'], 
            ['XCKRE0BWRHxfP1kZIihgtT+jUjSp2GE8v5ZlhcIhVmA'], 
            ['YI5Y79K6GXqAUoGP6PNyII8WKlAoel4urDxWSVVOvBw'], 
            ['ypklj+8GJ15rOIH1lpKQtFJOuK+VdvyCuBPqhY3aoM'], 
            ['ZSsAZ0Pq+MCqFrnjsRFn5Ua09pMCVaOV9c8ZuYb7XQY']]
  
# Create the pandas DataFrame
folders = pd.DataFrame(datasets, columns=['folder'])

#folders

# %%
timestamp = 0
# analyse the forms
allData = pd.DataFrame()
for indexFolder, folder in folders.iterrows():
    # check f the path exists (becouse kaggle removed the + character)
    from os.path import exists
    originalPath = baseFolder+folder['folder']+"/sleep_form_"+folder['folder']+".csv"
    if(not(exists(originalPath))):
        originalPath = baseFolder+folder['folder']+"/sleep_form_"+folder['folder'].replace("+","")+".csv"
   
    dataFLabel = pd.read_csv(localFolder+"form/sleep_form_"+folder['folder']+"_treated.csv",
                   delimiter=',', encoding="utf8")
    originalFLabel = pd.read_csv(originalPath, delimiter=',', encoding="utf8")
                                 
    print(folder['folder'])
    print("Original Count: ",originalFLabel.shape[0])
    print("New Count: ",dataFLabel.shape[0])
    print("Time sleep: ",dataFLabel['time_sleeping_hs'].max(),dataFLabel['time_sleeping_hs'].min(),dataFLabel['time_sleeping_hs'].mean())
    print("Sleep variability",)
    print("Count > 24:",dataFLabel[dataFLabel['time_sleeping_hs']>24].shape[0])
    print("Count <= 24 and > 12:",(dataFLabel[dataFLabel['time_sleeping_hs'] > 12 ].shape[0]-dataFLabel[dataFLabel['time_sleeping_hs']>24].shape[0]))
    print("Count <= 12:",dataFLabel[dataFLabel['time_sleeping_hs'] <= 12].shape[0])
    print("Count <= 0:",dataFLabel[dataFLabel['time_sleeping_hs'] <= 0].shape[0])
    print()
# Out:
# 0Jf4TH9Zzse0Z1Jjh7SnTOe2MMzeSnFi7feTnkG6vgs
# Original Count:  33
# New Count:  26
# Time sleep:  20.75333333333333 2.5 6.80219017094017
# Sleep variability
# Count > 24: 0
# Count <= 24 and > 12: 2
# Count <= 12: 24
# Count <= 0: 0
#
# 0tdmm6rwW3KquQ73ATYYJ5JkpMtvbppJ0VzA2GExdA
# Original Count:  31
# New Count:  22
# Time sleep:  22.50277777777778 2.5133333333333336 8.58574494949495
# Sleep variability
# Count > 24: 0
# Count <= 24 and > 12: 4
# Count <= 12: 18
# Count <= 0: 0
#
# 2cyV53lVyUtlMj0BRwilEWtYJwUiviYoL48cZBPBq0
# Original Count:  48
# New Count:  30
# Time sleep:  16.0 1.0 5.175129629629629
# Sleep variability
# Count > 24: 0
# Count <= 24 and > 12: 1
# Count <= 12: 29
# Count <= 0: 0
#
# 2J22RukYnEbKTk7t+iUVDBkorcyL5NKN6TrLe89ys
# Original Count:  50
# New Count:  21
# Time sleep:  33.004444444444445 4.0 14.673769841269843
# Sleep variability
# Count > 24: 6
# Count <= 24 and > 12: 1
# Count <= 12: 14
# Count <= 0: 0
#
# 7EYF5I04EVqisUJCVNHlqn77UAuOmwL2Dahxd3cA
# Original Count:  15
# New Count:  14
# Time sleep:  31.511111111111116 3.262222222222222 8.343055555555557
# Sleep variability
# Count > 24: 1
# Count <= 24 and > 12: 0
# Count <= 12: 13
# Count <= 0: 0
#
# a9Qgj8ENWrHvl9QqlXcIPKmyGMKgbfHk9Dbqon1HQP4
# Original Count:  50
# New Count:  25
# Time sleep:  33.50638888888889 3.25 15.60608888888889
# Sleep variability
# Count > 24: 8
# Count <= 24 and > 12: 4
# Count <= 12: 13
# Count <= 0: 0
#
# ae4JJBZDycEcY8McJF+3BxyvZ1619y03BNdCxzpZTc
# Original Count:  22
# New Count:  18
# Time sleep:  20.004166666666663 3.0 8.254413580246911
# Sleep variability
# Count > 24: 0
# Count <= 24 and > 12: 2
# Count <= 12: 16
# Count <= 0: 0
#
# Ch3u5Oaz96VSrQbf0z31X6jEIbeIekkC0mwPzCdeJ1U
# Original Count:  53
# New Count:  29
# Time sleep:  32.0125 1.0 9.849578544061304
# Sleep variability
# Count > 24: 5
# Count <= 24 and > 12: 0
# Count <= 12: 24
# Count <= 0: 0
#
# CH8f0yZkZL13zWuE9ks1CkVJRVrr+jsGdUXHrZ6YeA
# Original Count:  66
# New Count:  27
# Time sleep:  29.01388888888889 2.0 7.381069958847736
# Sleep variability
# Count > 24: 1
# Count <= 24 and > 12: 1
# Count <= 12: 25
# Count <= 0: 0
#
# DHO1K4jgiwZJOfQTrxvKE2vn7hkjamigroGD5IaeRc
# Original Count:  22
# New Count:  21
# Time sleep:  14.0 2.0 7.480701058201059
# Sleep variability
# Count > 24: 0
# Count <= 24 and > 12: 1
# Count <= 12: 20
# Count <= 0: 0
#
# DHPqzSqSttiba1L3BD1cptNJPjSxZ8rXxF9mY3za6WA
# Original Count:  6
# New Count:  3
# Time sleep:  18.003888888888888 0.7647222222222222 8.92287037037037
# Sleep variability
# Count > 24: 0
# Count <= 24 and > 12: 1
# Count <= 12: 2
# Count <= 0: 0
#
# dQEFscjqnIlug8Tgq97JohhSQPG2DEOWJqS86wCrcY
# Original Count:  66
# New Count:  32
# Time sleep:  348.2575 4.264166666666666 20.24129340277778
# Sleep variability
# Count > 24: 3
# Count <= 24 and > 12: 3
# Count <= 12: 26
# Count <= 0: 0
#
# HFvs2CohmhHte+AaCzFasjzegGzxZKPhkrX23iI6Xo
# Original Count:  49
# New Count:  27
# Time sleep:  30.50722222222222 1.0 10.245833333333334
# Sleep variability
# Count > 24: 4
# Count <= 24 and > 12: 1
# Count <= 12: 22
# Count <= 0: 0
#
# jgB9E8v3Z6PKdTRTCMAijBllA9YEMtrmHbe4qsbmJWw
# Original Count:  28
# New Count:  25
# Time sleep:  29.25027777777778 3.0 7.540299999999999
# Sleep variability
# Count > 24: 1
# Count <= 24 and > 12: 1
# Count <= 12: 23
# Count <= 0: 0
#
# JkY++R7E8myldLN3on6iQ78Ee78zCbrLuggfwGju3I
# Original Count:  52
# New Count:  30
# Time sleep:  18.26138888888889 3.5 7.0630092592592595
# Sleep variability
# Count > 24: 0
# Count <= 24 and > 12: 2
# Count <= 12: 28
# Count <= 0: 0
#
# K4SLohf+TN1Ak8Dn8iE3Lme7rEMPISfppB2sXfHX8
# Original Count:  42
# New Count:  23
# Time sleep:  32.76222222222222 3.0 8.004661835748792
# Sleep variability
# Count > 24: 1
# Count <= 24 and > 12: 0
# Count <= 12: 22
# Count <= 0: 0
#
# oGaWetJJJEWHuvYdWYo826SQxfhCExVVQ2da8LE1Y7Q
# Original Count:  50
# New Count:  37
# Time sleep:  102.7575 2.0 13.324932432432432
# Sleep variability
# Count > 24: 1
# Count <= 24 and > 12: 13
# Count <= 12: 23
# Count <= 0: 0
#
# pyt24oiDAHsmgWMvkFKz2fn2pwcHiXchd6KchLM
# Original Count:  22
# New Count:  20
# Time sleep:  26.76527777777778 3.0 8.904347222222222
# Sleep variability
# Count > 24: 2
# Count <= 24 and > 12: 1
# Count <= 12: 17
# Count <= 0: 0
#
# PZCf1nfvhR+6fk+7+sPNMYOgb8BAMmtQtfoRS83Suc
# Original Count:  9
# New Count:  7
# Time sleep:  712.0130555555555 6.0 107.85900793650794
# Sleep variability
# Count > 24: 1
# Count <= 24 and > 12: 0
# Count <= 12: 6
# Count <= 0: 0
#
# QUNCATForxzK0HHw46LrGOMWh0eVA8Y5XWEiUXX+cQ
# Original Count:  28
# New Count:  23
# Time sleep:  30.010277777777777 5.25 10.351328502415459
# Sleep variability
# Count > 24: 1
# Count <= 24 and > 12: 5
# Count <= 12: 17
# Count <= 0: 0
#
# rIl2UK9+bQ+tzpFdbJAdbBxEa5GbgrgC030yEaENLw
# Original Count:  19
# New Count:  19
# Time sleep:  32.26 1.75 11.650116959064327
# Sleep variability
# Count > 24: 4
# Count <= 24 and > 12: 0
# Count <= 12: 15
# Count <= 0: 0
#
# RoBW3cDOO9wWRMPO2twQff83MPc+OXn6gJ+a1DafreI
# Original Count:  40
# New Count:  29
# Time sleep:  30.51555555555556 0.25 7.475938697318007
# Sleep variability
# Count > 24: 1
# Count <= 24 and > 12: 1
# Count <= 12: 27
# Count <= 0: 0
#
# SH3kQeyd5volraxw8vOyhlowNqWBPr1IJ9URNXUL4
# Original Count:  20
# New Count:  19
# Time sleep:  9.016111111111112 1.0 5.198932748538011
# Sleep variability
# Count > 24: 0
# Count <= 24 and > 12: 0
# Count <= 12: 19
# Count <= 0: 0
#
# VVpwFNMrEglveh6MDN8lrRzTy5OwzglD4FURfM4A2is
# Original Count:  38
# New Count:  26
# Time sleep:  316.2502777777778 1.0 20.427916666666665
# Sleep variability
# Count > 24: 3
# Count <= 24 and > 12: 0
# Count <= 12: 23
# Count <= 0: 0
#
# Wa1mcNmbh66S7VS6GIzyfCFMD3SGhbtDQyFP1ywJEsw
# Original Count:  24
# New Count:  16
# Time sleep:  17.760277777777777 4.0 8.548385416666667
# Sleep variability
# Count > 24: 0
# Count <= 24 and > 12: 2
# Count <= 12: 14
# Count <= 0: 0
#
# XCKRE0BWRHxfP1kZIihgtT+jUjSp2GE8v5ZlhcIhVmA
# Original Count:  35
# New Count:  27
# Time sleep:  32.515277777777776 3.5077777777777777 7.7662962962962965
# Sleep variability
# Count > 24: 1
# Count <= 24 and > 12: 1
# Count <= 12: 25
# Count <= 0: 0
#
# YI5Y79K6GXqAUoGP6PNyII8WKlAoel4urDxWSVVOvBw
# Original Count:  25
# New Count:  25
# Time sleep:  44.504444444444445 2.508611111111111 11.236799999999999
# Sleep variability
# Count > 24: 2
# Count <= 24 and > 12: 3
# Count <= 12: 20
# Count <= 0: 0
#
# ypklj+8GJ15rOIH1lpKQtFJOuK+VdvyCuBPqhY3aoM
# Original Count:  1
# New Count:  1
# Time sleep:  15.0 15.0 15.0
# Sleep variability
# Count > 24: 0
# Count <= 24 and > 12: 1
# Count <= 12: 0
# Count <= 0: 0
#
# ZSsAZ0Pq+MCqFrnjsRFn5Ua09pMCVaOV9c8ZuYb7XQY
# Original Count:  21
# New Count:  20
# Time sleep:  36.00944444444444 1.0125 9.553388888888886
# Sleep variability
# Count > 24: 1
# Count <= 24 and > 12: 3
# Count <= 12: 16
# Count <= 0: 0
